# %%
#task 2 - Superstore_USA
1 . load this data in sql and in pandas with a relation in sql  
2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table 
3 . Find out how return that we ahve recived and with a product id 
4 . try  to join order and return data both in sql and pandas 
5 . Try to find out how many unique customer that we have 
6 . try to find out in how many regions we are selling a product and who is a manager for a respective region 
7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 
8 . Create a new coulmn and try to find our a diffrence between order date and shipment date
9 . base on question number 8 find out for which order id we have shipment duration more than 10 days 
10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 
11 . Gorup by region and find out which region is more profitable 
12 . Try to find out overalll in which country we are giving more didscount 
13 . Give me a list of unique postal code 
14 . which customer segement is more profitalble find it out . 
15 . try to find out the 10th most loss making product catagory . 
16 . Try to find out 10 top  product with highest margins

# %%
# 1 . load this data in sql in pandas


import pandas as pd

# %%
"""
    Reading sheet 1 (Orders) from excel in pandas

"""

df_data1 = pd.read_excel('D:/FSDS-iNeuron/3.Resource/31stJulyliveclassPandas/Superstore_USA.xlsx', sheet_name=0)

# %%
df_data1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 3     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 4     West        Washington  Anacortes        98221 2011-07-27 2011-07-27
#
#      Profit  Quantity ordered new    Sales Order ID
# 0    1.3200                     2     5.90    88525
# 1    4.5600                     4    13.01    88522
# 2  -47.6400                     7    49.92    88523
# 3  -30.5100                     7    41.64    88523
# 4  998.2023                     8  1446.67    88523
#
# [5 rows x 24 columns]

# %%
"""
    Reading sheet 2(Returns) from excel in pandas

"""

df_data2 = pd.read_excel('D:/FSDS-iNeuron/3.Resource/31stJulyliveclassPandas/Superstore_USA.xlsx', sheet_name=1)

# %%
df_data2.head()
# Out:
#    Order ID    Status
# 0        65  Returned
# 1       612  Returned
# 2       614  Returned
# 3       678  Returned
# 4       710  Returned

# %%
"""
    Reading sheet 3(Users) from excel in pandas

"""

df_data3 = pd.read_excel('D:/FSDS-iNeuron/3.Resource/31stJulyliveclassPandas/Superstore_USA.xlsx', sheet_name=2)

# %%
df_data3
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
# 2 loading data automatically in sql

df_data1.to_csv('D:/FSDS-iNeuron/3.Resource/31stJulyliveclassPandas/Orders_Superstore_USA.csv')
df_data2.to_csv('D:/FSDS-iNeuron/3.Resource/31stJulyliveclassPandas/Returns_Superstore_USA.csv')
df_data3.to_csv('D:/FSDS-iNeuron/3.Resource/31stJulyliveclassPandas/Users_Superstore_USA.csv')

# !csvsql --db mysql://root:Root_mysql@localhost:3306/practice --insert Orders_Superstore_USA.csv
# !csvsql --db mysql://root:Root_mysql@localhost:3306/practice --insert Returns_Superstore_USA.csv
# !csvsql --db mysql://root:Root_mysql@localhost:3306/practice --insert Users_Superstore_USA.csv
# Out:
# C:\Users\Sai\anaconda3\lib\site-packages\agate\table\from_csv.py:74: RuntimeWarning: Error sniffing CSV dialect: Could not determine delimiter
# C:\Users\Sai\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".
# C:\Users\Sai\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".
# C:\Users\Sai\anaconda3\lib\site-packages\agate\utils.py:285: UnnamedColumnWarning: Column 0 has no name. Using "a".

# %%
# 3 . Find out how return that we ahve recived and with a product id 

k = pd.DataFrame(df_data1[['Order ID', 'Product Name']])
l = pd.DataFrame(df_data2['Order ID'])
pd.merge(k,l,how='inner')

# It won't be possible to to find product name for all the 'Order Id' in dataset2/ returns sheet because they are not included in df_data1 and hence it is not available
# How ever on programming the inner join (as done on the above) we got 98 'Order ID' to be common in df_data1 and df_data2.
# Out:
#     Order ID                                       Product Name
# 0       9895              Dixon My First Ticonderoga Pencil, #2
# 1      13959                                          Avery 493
# 2      13959                              EcoTones® Memo Sheets
# 3      36038                                          Newell 35
# 4      39490                  Staples SlimLine Pencil Sharpener
# ..       ...                                                ...
# 93      7107  Snap-A-Way® Black Print Carbonless Ruled Speed...
# 94      7107  Recycled Steel Personal File for Standard File...
# 95     42823                                         Xerox 1980
# 96     13638                                   TDK 4.7GB DVD+RW
# 97     47109                        SAFCO Folding Chair Trolley
#
# [98 rows x 2 columns]

# %%
# 4 . try  to join order and return data both in sql and pandas 

k = pd.DataFrame(df_data1[['Order ID', 'Product Name']])
l = pd.DataFrame(df_data2['Order ID'])
pd.merge(k,l)
# Out:
#     Order ID                                       Product Name
# 0       9895              Dixon My First Ticonderoga Pencil, #2
# 1      13959                                          Avery 493
# 2      13959                              EcoTones® Memo Sheets
# 3      36038                                          Newell 35
# 4      39490                  Staples SlimLine Pencil Sharpener
# ..       ...                                                ...
# 93      7107  Snap-A-Way® Black Print Carbonless Ruled Speed...
# 94      7107  Recycled Steel Personal File for Standard File...
# 95     42823                                         Xerox 1980
# 96     13638                                   TDK 4.7GB DVD+RW
# 97     47109                        SAFCO Folding Chair Trolley
#
# [98 rows x 2 columns]

# %%
# 5 . Try to find out how many unique customer that we have 

pd.DataFrame(df_data1['Customer Name'].unique())
# Out:
#                     0
# 0     Janice Fletcher
# 1       Bonnie Potter
# 2      Ronnie Proctor
# 3        Dwight Hwang
# 4           Leon Gill
# ...               ...
# 2698    Marc McDaniel
# 2699      Marvin Reid
# 2700    Florence Gold
# 2701   Frederick Cole
# 2702    Tammy Buckley
#
# [2703 rows x 1 columns]

# %%
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region 

prod_unique = pd.DataFrame(df_data1['Product Name'].unique())
k = pd.DataFrame(df_data1[['Region', 'Product Name']])
l = pd.DataFrame(df_data3[['Region', 'Manager']])
managers = pd.merge(k,l, on = "Region")
managers
# Out:
#        Region                                       Product Name Manager
# 0     Central                                           Avery 49   Chris
# 1     Central  Howard Miller 12-3/4 Diameter Accuwave DS ™ Wa...   Chris
# 2     Central                                         Newell 321   Chris
# 3     Central                                         Newell 351   Chris
# 4     Central           OIC Colored Binder Clips, Assorted Sizes   Chris
# ...       ...                                                ...     ...
# 9421    South           Staples Copy Paper (20Lb. and 84 Bright)     Sam
# 9422    South            O'Sullivan 3-Shelf Heavy-Duty Bookcases     Sam
# 9423    South                  Logitech Cordless Access Keyboard     Sam
# 9424    South                      Contemporary Wood/Metal Frame     Sam
# 9425    South  Universal Premium White Copier/Laser Paper (20...     Sam
#
# [9426 rows x 3 columns]

# %%
df_data1
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
#         Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0     Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2       Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3       Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4       Bonnie Potter     Express Air        Corporate       Technology  ...
# ...               ...             ...              ...              ...  ...
# 9421   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9422   Frederick Cole     Regular Air         Consumer  Office Supplies  ...
# 9423   Frederick Cole  Delivery Truck         Consumer        Furniture  ...
# 9424    Tammy Buckley     Express Air         Consumer        Furniture  ...
# 9425    Tammy Buckley     Express Air         Consumer  Office Supplies  ...
#
#        Region State or Province        City  Postal Code Order Date  \
# 0     Central          Illinois     Addison        60101 2012-05-28
# 1        West        Washington   Anacortes        98221 2010-07-07
# 2        West        Washington   Anacortes        98221 2011-07-27
# 3        West        Washington   Anacortes        98221 2011-07-27
# 4        West        Washington   Anacortes        98221 2011-07-27
# ...       ...               ...         ...          ...        ...
# 9421     East     West Virginia  Charleston        25314 2013-05-14
# 9422     East     West Virginia  Charleston        25314 2013-05-14
# 9423     East     West Virginia  Charleston        25314 2013-09-12
# 9424     West           Wyoming    Cheyenne        82001 2010-02-08
# 9425     West           Wyoming    Cheyenne        82001 2013-09-12
#
#       Ship Date       Profit  Quantity ordered new    Sales Order ID
# 0    2012-05-30     1.320000                     2     5.90    88525
# 1    2010-07-08     4.560000                     4    13.01    88522
# 2    2011-07-28   -47.640000                     7    49.92    88523
# 3    2011-07-28   -30.510000                     7    41.64    88523
# 4    2011-07-27   998.202300                     8  1446.67    88523
# ...         ...          ...                   ...      ...      ...
# 9421 2013-05-15   137.860000                    13   447.87    87532
# 9422 2013-05-14   -39.070000                     3    13.23    87532
# 9423 2013-09-14 -1225.029097                     4  2215.93    87533
# 9424 2010-02-11   349.485000                     5   506.50    87530
# 9425 2013-09-14    78.062400                    23   172.48    87533
#
# [9426 rows x 24 columns]

# %%
df_data1.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
# 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset 

k = pd.DataFrame(df_data1['Ship Mode'])
Reg_Air = (len(k[k['Ship Mode'] == 'Regular Air'])/len(k))*100
Express_Air = (len(k[k['Ship Mode'] == 'Express Air'])/len(k))*100
Delivery_Truck = (len(k[k['Ship Mode'] == 'Delivery Truck'])/len(k))*100
print('Mode : Regular mode percentage : ',Reg_Air,'\n','Mode : Express Air Percentage : ',Express_Air,'\n','Mode : Delivery Truck : ',Delivery_Truck)
# Out:
# Mode : Regular mode percentage :  74.64460004243581
#  Mode : Express Air Percentage :  11.744112030553786
#  Mode : Delivery Truck :  13.611287927010396

# %%
df_data1['Ship Mode'].unique()
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
# 8 . Create a new coulmn and try to find out a diffrence between order date and shipment date

df_data1['Delivery Time(days)'] = df_data1['Ship Date'] - df_data1['Order Date']
type(df_data1['Delivery Time(days)'][0])
df_data1['Delivery Time(days)']
# Out:
# 0      2 days
# 1      1 days
# 2      1 days
# 3      1 days
# 4      0 days
#         ...
# 9421   1 days
# 9422   0 days
# 9423   2 days
# 9424   3 days
# 9425   2 days
# Name: Delivery Time(days), Length: 9426, dtype: timedelta64[ns]

# %%
# Other approach

df_data1['Delivery Time(days)'] = df_data1['Ship Date'].dt.day - df_data1['Order Date'].dt.day

# %%
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days 

# Converting time delta format to str/object
df_data1['Delivery Time(days)'] = df_data1['Delivery Time(days)'].astype(str)

# Strip "days" from Delivery_Time column
df_data1['Delivery Time(days)'] = df_data1['Delivery Time(days)'].str.replace('days', "")

# Converting to int format to perform operations
df_data1['Delivery Time(days)'] = df_data1['Delivery Time(days)'].astype(int)

df_data1[df_data1['Delivery Time(days)'] > 10]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# 5673   19005            Low      0.06       65.99           2.50         2088
# 5859   24392            Low      0.05       29.89           1.99         2143
# 5881   21257            Low      0.05        7.99           5.03         2153
# 8607   26351         Medium      0.00        8.32           2.38         3119
# 8609   26350         Medium      0.07      180.98          55.24         3119
# 8610   26352         Medium      0.06        4.20           2.26         3119
# 8973   20750            Low      0.06      125.99           8.08         3248
# 8982    2748            Low      0.03       11.97           5.81         3251
# 8983    2749            Low      0.08      195.99           4.20         3251
# 8993    2750            Low      0.06      125.99           8.08         3251
# 8996   20748            Low      0.03       11.97           5.81         3252
# 8997   20749            Low      0.08      195.99           4.20         3252
#
#                 Customer Name       Ship Mode Customer Segment  \
# 643   Brenda Nelson Blanchard     Regular Air        Corporate
# 1548               Dana Desai     Regular Air   Small Business
# 1549               Dana Desai     Express Air   Small Business
# 1678       Christopher Bryant  Delivery Truck         Consumer
# 1679       Christopher Bryant     Regular Air         Consumer
# 1680       Christopher Bryant     Regular Air         Consumer
# 1697               Neal Wolfe  Delivery Truck         Consumer
# 1698               Neal Wolfe     Regular Air         Consumer
# 1699               Neal Wolfe     Regular Air         Consumer
# 2515          Virginia Rivera     Regular Air      Home Office
# 5548          Ricky Dougherty     Regular Air         Consumer
# 5673             Carrie Boyle     Regular Air        Corporate
# 5859            Lester Sawyer     Regular Air      Home Office
# 5881               Anna Glenn     Regular Air      Home Office
# 8607              Jay Hubbard     Express Air        Corporate
# 8609              Jay Hubbard  Delivery Truck        Corporate
# 8610              Jay Hubbard     Regular Air        Corporate
# 8973            Earl Donnelly     Express Air        Corporate
# 8982             Peter Brooks     Regular Air        Corporate
# 8983             Peter Brooks     Regular Air        Corporate
# 8993             Peter Brooks     Express Air        Corporate
# 8996           Milton Harrell     Regular Air        Corporate
# 8997           Milton Harrell     Regular Air        Corporate
#
#      Product Category  ... State or Province           City Postal Code  \
# 643   Office Supplies  ...         Minnesota      Richfield       55423
# 1548       Technology  ...           Indiana    Bloomington       47401
# 1549  Office Supplies  ...           Indiana    Bloomington       47401
# 1678        Furniture  ...        California    Santa Clara       95051
# 1679  Office Supplies  ...        California    Santa Clara       95051
# 1680       Technology  ...        California    Santa Clara       95051
# 1697        Furniture  ...        Washington        Seattle       98119
# 1698  Office Supplies  ...        Washington        Seattle       98119
# 1699       Technology  ...        Washington        Seattle       98119
# 2515  Office Supplies  ...        California   Redwood City       94061
# 5548  Office Supplies  ...      South Dakota      Brookings       57006
# 5673       Technology  ...          New York   Mount Vernon       10550
# 5859       Technology  ...          Virginia        Fairfax       20151
# 5881       Technology  ...        California       Pasadena       91104
# 8607       Technology  ...           Florida        Orlando       32839
# 8609  Office Supplies  ...           Florida        Orlando       32839
# 8610  Office Supplies  ...           Florida        Orlando       32839
# 8973       Technology  ...         Louisiana        Slidell       70458
# 8982  Office Supplies  ...          New York  New York City       10112
# 8983       Technology  ...          New York  New York City       10112
# 8993       Technology  ...          New York  New York City       10112
# 8996  Office Supplies  ...          New York      Rotterdam       12306
# 8997       Technology  ...          New York      Rotterdam       12306
#
#       Order Date  Ship Date     Profit Quantity ordered new     Sales  \
# 643   2011-12-29 2012-03-22    58.5000                   19    204.67
# 1548  2011-12-30 2012-01-10   375.7050                    6    587.46
# 1549  2011-12-30 2012-01-14   -47.3950                   12     79.37
# 1678  2011-12-30 2012-01-16  -211.8850                   21   2699.94
# 1679  2011-12-30 2012-01-10   355.0119                   10    514.51
# 1680  2011-12-30 2012-01-27  1021.4001                   16   1480.29
# 1697  2011-12-30 2012-01-16  -423.7700                   83  10671.20
# 1698  2011-12-30 2012-01-10   469.6900                   41   2109.51
# 1699  2011-12-30 2012-01-27   727.3620                   65   6013.69
# 2515  2011-12-30 2012-03-31     5.8200                   10     22.35
# 5548  2011-12-30 2012-01-13    66.2250                   21    121.51
# 5673  2011-12-28 2012-01-14   187.4880                    8    451.34
# 5859  2011-12-26 2012-01-17  4230.2001                   12    344.16
# 5881  2011-12-26 2012-01-19   -23.4520                    2     15.56
# 8607  2011-12-29 2012-01-16 -1075.3960                   19    170.62
# 8609  2013-12-29 2014-01-15  -147.5180                   25   4529.95
# 8610  2013-12-29 2014-01-17  -689.8738                    2      9.64
# 8973  2011-12-26 2012-01-14     2.4780                   20   2180.31
# 8982  2011-12-26 2012-01-22   -31.7400                   31    388.52
# 8983  2011-12-26 2012-01-26  -557.9530                   13   2092.05
# 8993  2013-12-26 2014-01-14  1304.5590                   86   9375.35
# 8996  2011-12-26 2012-01-22   -15.8700                    8    100.26
# 8997  2011-12-26 2012-01-26  -278.9765                    3    482.78
#
#      Order ID Delivery Time(days)
# 643     87215                  84
# 1548    86318                  11
# 1549    86318                  15
# 1678    87957                  17
# 1679    87957                  11
# 1680    87957                  28
# 1697    19556                  17
# 1698    19556                  11
# 1699    19556                  28
# 2515    86177                  92
# 5548    88223                  14
# 5673    88352                  17
# 5859    87572                  22
# 5881    91294                  24
# 8607    86434                  18
# 8609    86436                  17
# 8610    86436                  19
# 8973    87300                  19
# 8982    19841                  27
# 8983    19841                  31
# 8993    19841                  19
# 8996    87300                  27
# 8997    87300                  31
#
# [23 rows x 25 columns]

# %%
# 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well 

# Inner join to find common orders
return_orders = pd.merge(df_data1, df_data2, how='inner')

# finding number of days
return_orders['Delivery_Time(days)'] = df_data1['Ship Date'] - df_data1['Order Date']

# converting column to str/obj type
return_orders['Delivery_Time(days)'] = return_orders['Delivery_Time(days)'].astype(str)

return_orders['Delivery_Time(days)']

# Removing the substring day
return_orders['Delivery_Time(days)'] = return_orders['Delivery_Time(days)'].str.replace('days','')

# Converting to int to perform operations
# Removing the substring day
return_orders['Delivery_Time(days)'] = return_orders['Delivery_Time(days)'].astype(int)

return_orders[return_orders['Delivery_Time(days)'] > 15]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, Delivery Time(days), Status, Delivery_Time(days)]
# Index: []
#
# [0 rows x 27 columns]

# %%
# 11 . Gorup by region and find out which region is more profitable 

max_profit_region = df_data1[['Region', 'Profit']].groupby('Region').sum().reset_index()
max_profit_region[max_profit_region['Profit'] == max(max_profit_region['Profit'])]
# Out:
#     Region         Profit
# 0  Central  519825.567067

# %%
# 12 . Try to find out overalll in which country we are giving more didscount 

max_discount_country = df_data1[['State or Province', 'Discount']].groupby('State or Province').sum().reset_index()
max_discount_country[max_discount_country['Discount'] == max(max_discount_country['Discount'])]
# Out:
#   State or Province  Discount
# 3        California     52.28

# %%
# 13 . Give me a list of unique postal code 

postal_codes = []
for i in df_data1['Postal Code'].unique():
    postal_codes.append(i)
    
print(postal_codes)
# Out:
# [60101, 98221, 91776, 95123, 2724, 3110, 8101, 8109, 7203, 2907, 55372, 11787, 13210, 59405, 59601, 59801, 68005, 10012, 92653, 92677, 92530, 92630, 90712, 93534, 90260, 97405, 97526, 97030, 97123, 97303, 62002, 98373, 98052, 75019, 23834, 62701, 60107, 60477, 14150, 12180, 77642, 75080, 77471, 78664, 75088, 24153, 94043, 92563, 94559, 10177, 2917, 5401, 4070, 2331, 8830, 8701, 7470, 7481, 5201, 97035, 44708, 45231, 44105, 95687, 5451, 94591, 70056, 22102, 60601, 66209, 66215, 66502, 66062, 6510, 4401, 4005, 2129, 2038, 1852, 1752, 2067, 3820, 8618, 7644, 7110, 8861, 7095, 2895, 97128, 97504, 98103, 84118, 84041, 93277, 76903, 78207, 60004, 94952, 1510, 1106, 1880, 6401, 6360, 2664, 15122, 76148, 5439, 5403, 37664, 37918, 37086, 37087, 80525, 80817, 60452, 76131, 98059, 99352, 37804, 70802, 4092, 7024, 76240, 98158, 78415, 94122, 4011, 4240, 2474, 2540, 1580, 3038, 60505, 84043, 84321, 66212, 48138, 85335, 74006, 75217, 77536, 90660, 13501, 11580, 63114, 84044, 84047, 84107, 60453, 2021, 2766, 7101, 28227, 60302, 60462, 50208, 80027, 66203, 81503, 80634, 37922, 38109, 55423, 55901, 55113, 80126, 80232, 17331, 33772, 87505, 12208, 44106, 43229, 78589, 86001, 85234, 85301, 30297, 28204, 6824, 6111, 6226, 7109, 66614, 67212, 80538, 80233, 80134, 6830, 6770, 6855, 4073, 1069, 2725, 21234, 21128, 21208, 20854, 98115, 91945, 94404, 60130, 1007, 7111, 8052, 21133, 60510, 3045, 7410, 97045, 97206, 44221, 6478, 33181, 4101, 3246, 3101, 7010, 2878, 33132, 13601, 85338, 86401, 19406, 93727, 4072, 7628, 7071, 2816, 2910, 2886, 94601, 2149, 1840, 48234, 37814, 62223, 61008, 61701, 60440, 19026, 68025, 68801, 68847, 68502, 48509, 63105, 13021, 13905, 28001, 45406, 43015, 95240, 90805, 4901, 8360, 78666, 7026, 93405, 94403, 2358, 7201, 7032, 7666, 68104, 89701, 94583, 92704, 6010, 6108, 4330, 1462, 2370, 7047, 7480, 61801, 68701, 56301, 94024, 93635, 95032, 90266, 1923, 2457, 3054, 8332, 90069, 92683, 90604, 2019, 1915, 2341, 7506, 8601, 30318, 1845, 39180, 11704, 11795, 60543, 95020, 4106, 2062, 7042, 10154, 24281, 37130, 84404, 84057, 55416, 46041, 42104, 41011, 95336, 4038, 2148, 8753, 76067, 11226, 97756, 85204, 85737, 84062, 64064, 63043, 22025, 60061, 93101, 95051, 26501, 88201, 78155, 75090, 90008, 68046, 84604, 60067, 60068, 60087, 60185, 75081, 60187, 60090, 39701, 89015, 61554, 61604, 91767, 6415, 4210, 2032, 1801, 3301, 8021, 7031, 7054, 60091, 60517, 46016, 47401, 46032, 47201, 21136, 81001, 90045, 14224, 10605, 10701, 97301, 97477, 97224, 81007, 48195, 5701, 43952, 20852, 20602, 55106, 55378, 95062, 93454, 98119, 60544, 62301, 55379, 60089, 89115, 91730, 2116, 1540, 77373, 37211, 75203, 52501, 64133, 63301, 64506, 98387, 99207, 98408, 77478, 63116, 63376, 80229, 80030, 46307, 46312, 98105, 90041, 90405, 95404, 95070, 6040, 6460, 6850, 6702, 1520, 2152, 7067, 2840, 48841, 89031, 89041, 41042, 6614, 1803, 1420, 1089, 2190, 3053, 3079, 7003, 7016, 7039, 8232, 7901, 85345, 85023, 60423, 40324, 86301, 86314, 97062, 61201, 98661, 14215, 61107, 97068, 18103, 16602, 72143, 92054, 6033, 6484, 6437, 92691, 95351, 6512, 7001, 73064, 27502, 84067, 29915, 84106, 32168, 37830, 42420, 85254, 8046, 99362, 37167, 37174, 79605, 75002, 79109, 71854, 80033, 21222, 6511, 8002, 91745, 93117, 6114, 2210, 1450, 1060, 3839, 92544, 92345, 6405, 6810, 6492, 75503, 77590, 46514, 55126, 89502, 66202, 11575, 85635, 93422, 20746, 76017, 78745, 77520, 77705, 76021, 89431, 20024, 83616, 76201, 33430, 10039, 1887, 7652, 42240, 26003, 78521, 77803, 76028, 96003, 92374, 1463, 7008, 8857, 7050, 7501, 90278, 6776, 2127, 1605, 7002, 2914, 90049, 75482, 75067, 19901, 19711, 94061, 60610, 6105, 2108, 3842, 92503, 95677, 2339, 1841, 7079, 91761, 1718, 1701, 1040, 2151, 7650, 93030, 3431, 7601, 7450, 11720, 60459, 7712, 72022, 28806, 27217, 27511, 66762, 55125, 15221, 11722, 14225, 11725, 27514, 28205, 28027, 27707, 43017, 15102, 95695, 95991, 92399, 90004, 6473, 2109, 7030, 85351, 85374, 3060, 2864, 11727, 10573, 60409, 62901, 18018, 60441, 60174, 60193, 60076, 11729, 1 ...

# %%
# 14 . which customer segement is more profitalble find it out . 

max_profit_customer_segment = df_data1[['Customer Segment', 'Profit']].groupby('Customer Segment').sum().reset_index()
max_profit_customer_segment[max_profit_customer_segment['Profit'] == max(max_profit_customer_segment['Profit'])]
# Out:
#   Customer Segment         Profit
# 1        Corporate  505538.627783

# %%
# 15 . try to find out the 10th most loss making product catagory .

category = df_data1[['Product Category', 'Profit']]
loss = category[category['Profit'] < 0].groupby('Product Category').sum().reset_index()
loss[loss['Profit'] == min(loss['Profit'])]
loss
# Out:
#   Product Category         Profit
# 0        Furniture -410464.845289
# 1  Office Supplies -393433.301145
# 2       Technology -358842.689349

# %%
# 16 . Try to find out 10 top  product with highest margins 

a = df_data1[['Product Base Margin', 'Product Name']]
b = pd.DataFrame(a[a['Product Base Margin'] == max(a['Product Base Margin'])])
b
# Out:
#       Product Base Margin                                       Product Name
# 230                  0.85                   Belkin OmniView SE Rackmount Kit
# 253                  0.85                                        Accessory27
# 262                  0.85                                        Accessory27
# 686                  0.85  Office Impressions Heavy Duty Welded Shelving ...
# 742                  0.85                                        Accessory27
# 807                  0.85                                        Accessory27
# 816                  0.85                                        Accessory27
# 881                  0.85                  Sterling Rubber Bands by Alliance
# 963                  0.85                                         Accessory4
# 976                  0.85                                         Accessory4
# 1567                 0.85                                        Accessory27
# 1718                 0.85                                         Accessory4
# 1723                 0.85                  Sterling Rubber Bands by Alliance
# 1887                 0.85  Office Impressions Heavy Duty Welded Shelving ...
# 1918                 0.85  Office Impressions Heavy Duty Welded Shelving ...
# 2116                 0.85                                        Accessory27
# 2138                 0.85                  Sterling Rubber Bands by Alliance
# 3174                 0.85                  Sterling Rubber Bands by Alliance
# 3428                 0.85                   Belkin OmniView SE Rackmount Kit
# 3963                 0.85  Office Impressions Heavy Duty Welded Shelving ...
# 3994                 0.85  Office Impressions Heavy Duty Welded Shelving ...
# 4015                 0.85                                         Accessory4
# 4168                 0.85                  Sterling Rubber Bands by Alliance
# 4632                 0.85                                         Accessory4
# 4756                 0.85                                         Accessory4
# 5149                 0.85                                         Accessory4
# 5180                 0.85                                         Accessory4
# 5672                 0.85                                         Accessory4
# 5860                 0.85  Office Impressions Heavy Duty Welded Shelving ...
# 7112                 0.85                                         Accessory4
# 7176                 0.85  Office Impressions Heavy Duty Welded Shelving ...
# 7202                 0.85  Office Impressions Heavy Duty Welded Shelving ...
# 7607                 0.85                                        Accessory27
# 7869                 0.85                                         Accessory4
# 7958                 0.85  Office Impressions Heavy Duty Welded Shelving ...
# 8077                 0.85                                         Accessory4
# 8725                 0.85                                         Accessory4
# 8950                 0.85                   Belkin OmniView SE Rackmount Kit
# 9145                 0.85                                        Accessory27
# 9377                 0.85  Office Impressions Heavy Duty Welded Shelving ...

# %%
# 16 . Try to find out 10 top  product with highest margins 

highest_product_margin = df_data1[['Product Name', 'Product Base Margin']].groupby('Product Name').mean()
highest_product_margin.sort_values(by='Product Base Margin', ascending=False).head(10)
# Out:
#                                                     Product Base Margin
# Product Name
# Office Impressions Heavy Duty Welded Shelving &...                 0.85
# Accessory27                                                        0.85
# Sterling Rubber Bands by Alliance                                  0.85
# Belkin OmniView SE Rackmount Kit                                   0.85
# Accessory4                                                         0.85
# Tennsco Stur-D-Stor Boltless Shelving, 5 Shelve...                 0.84
# Tennsco Commercial Shelving                                        0.84
# Serrated Blade or Curved Handle Hand Letter Ope...                 0.84
# Accessory36                                                        0.83
# Eldon Shelf Savers™ Cubes and Bins                                 0.83
