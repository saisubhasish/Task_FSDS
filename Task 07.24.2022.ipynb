# %%
Mysql : 
    
    1. Create a  table attribute dataset and dress dataset
    2. Do a bulk load for these two table for respective dataset 
    3. read these dataset in pandas as a dataframe 
    4. Convert attribute dataset in json format 
    5. Store this dataset into mongodb
    6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID
    7. Write a sql query to find out how many unique dress that we have based on dress id 
    8. Try to find out how mnay dress is having recommendation 0
    9. Try to find out total dress sell for individual dress id 
    10. Try to find out a third highest most selling dress id

# %%
#Import packages and connect to MySQL

import mysql.connector as conn
import pymongo
import json
import csv
import pandas as pd

connection = conn.connect(host = "localhost" , user ="root" , passwd = "Sai@9556332113" )
cursor = mydb.cursor()

# %%
#Create a database and use it

q = "create database if not exists sqldb"
cursor.execute(q)
q = "use sqldb"
cursor.execute(q)

# %%
#Create tables for attribute dataset

q = "create table if not exists sqldb.attributeTable(Dress_ID varchar(10), Style varchar(10), Price varchar(10), Rating varchar(10), Size varchar(10), Season varchar(10), NeckLine varchar(25), SleeveLength varchar(25), waiseline varchar(25), Material varchar(25), FabricType varchar(25), Decoration varchar(25),Pattern_Type varchar(25), Recommendation varchar(10))"
cursor.execute(q)

# %%
#Create tables for dress dataset

q = "create table if not exists sqldb.salesTable(Dress_ID varchar(25),`29/8/2013` varchar(25),`31/8/2013` varchar(25),`2013-02-09` varchar(25),`2013-04-09` varchar(25),`2013-06-09` varchar(25),`2013-08-09` varchar(25),`2013-10-09` varchar(25),`2013-12-09` varchar(25),`14/9/2013` varchar(25),`16/9/2013` varchar(25),`18/9/2013` varchar(25),`20/9/2013` varchar(25),`22/9/2013` varchar(25),`24/9/2013` varchar(25),`26/9/2013` varchar(25),`28/9/2013` varchar(25),`30/9/2013` varchar(25),`2013-02-10` varchar(25),`2013-04-10` varchar(25),`2013-06-10` varchar(25),`2010-08-10` varchar(25),`2013-10-10` varchar(25),`2013-12-10` varchar(25))"
cursor.execute(q)

# %%
#Reading excel file in pandas for further operation

df = pd.read_excel('D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\AttributeDataSet.xlsx')

# %%
#Convering file to csv 

df.to_csv('D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\AttributeDataSet.csv', index=False)

# %%
#Bulk load the data (from datasets) into the tables

csv_data = csv.reader(open('D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\AttributeDataSet.csv'))
header = next(csv_data)
for row in csv_data:
    cursor.execute("insert into attributeTable(Dress_ID, Style, Price, Rating, Size, Season, NeckLine, SleeveLength, waiseline, Material, FabricType, Decoration, Pattern_Type, Recommendation) values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)", row)
mydb.commit()

# %%
#Reading excel file in pandas for further operation

df1 = pd.read_excel('D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\Dress Sales.xlsx')

# %%
#Convering file to csv 

df1.to_csv('D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\DressSales.csv', index=False)

# %%
#Bulk load the data (from datasets) into the tables

csv_data = csv.reader(open('D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\DressSales.csv'))
header = next(csv_data)
for row in csv_data:
    cursor.execute("insert into salesTable(Dress_ID ,`29/8/2013` ,`31/8/2013` ,`2013-02-09` ,`2013-04-09` ,`2013-06-09` ,`2013-08-09` ,`2013-10-09` ,`2013-12-09` ,`14/9/2013` ,`16/9/2013` ,`18/9/2013` ,`20/9/2013` ,`22/9/2013` ,`24/9/2013` ,`26/9/2013` ,`28/9/2013` ,`30/9/2013` ,`2013-02-10` ,`2013-04-10` ,`2013-06-10` ,`2010-08-10` ,`2013-10-10` ,`2013-12-10`) values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s, %s)", row)
mydb.commit()

# %%
#Create Dataframes using data in the two tables

cursor.execute('use sqldb')

cursor.execute('SELECT * FROM attributeTable')
table_rows = cursor.fetchall()

df_attribute = pd.DataFrame(table_rows)
df_attribute.columns = ['Dress_ID','Style','Price','Rating','Size','Season','NeckLine','SleeveLength','Waiseline','Material','FabricType','Decoration','Pattern Type','Recommendation']

# %%
#Create two Dataframes using data in the two tables

cursor.execute('SELECT * FROM salesTable')
table_rows = cursor.fetchall()

df_sales = pd.DataFrame(table_rows)
df_sales.columns = ['Dress_ID','29/8/2013','31/8/2013','2013-02-09','2013-04-09','2013-06-09','2013-08-09','2013-10-09','2013-12-09','14/9/2013','16/9/2013','18/9/2013','20/9/2013','22/9/2013','24/9/2013','26/9/2013','28/9/2013','30/9/2013','2013-02-10','2013-04-10','2013-06-10','2010-08-10','2013-10-10','2013-12-10']

# %%
df_attribute.head()
# Out:
#      Dress_ID    Style    Price Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low    4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low    0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High    0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average    4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low    4.5    M  Summer   o-neck    butterfly
#
#   Waiseline       Material FabricType  Decoration Pattern Type Recommendation
# 0    empire                   chiffon     ruffles       animal              1
# 1   natural     microfiber                ruffles       animal              0
# 2   natural       polyster                               print              0
# 3   natural           silk    chiffon  embroidary        print              1
# 4   natural  chiffonfabric    chiffon         bow          dot              0

# %%
df_sales.head()
# Out:
#      Dress_ID 29/8/2013 31/8/2013 2013-02-09 2013-04-09 2013-06-09 2013-08-09  \
# 0  1006032852      2114      2274       2491       2660       2727       2887
# 1  1212192089       151       275        570        750        813       1066
# 2  1190380701         6         7          7          7          8          8
# 3   966005983      1005      1128       1326       1455       1507       1621
# 4   876339541       996      1175       1304       1396       1432       1559
#
#   2013-10-09 2013-12-09 14/9/2013  ... 24/9/2013 26/9/2013 28/9/2013  \
# 0       2930       3119      3204  ...      3554    3624.0      3706
# 1       1164       1558      1756  ...      2710    2942.0      3258
# 2          9         10        10  ...        11      11.0        11
# 3       1637       1723      1746  ...      1878    1892.0      1914
# 4       1570       1638      1655  ...      2032    2156.0      2252
#
#   30/9/2013 2013-02-10 2013-04-10 2013-06-10 2010-08-10 2013-10-10 2013-12-10
# ...

# %%
#Convert dataframes to json format

df_attribute.to_json("D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\AttributeDataSet.json")
df_attribute.to_json("D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\DressSalesDataSet.json")

# %%
#Store this dataset into mongodb

client = pymongo.MongoClient("mongodb://sai1118:Sai1234@ac-hfsjren-shard-00-00.d8m7g8f.mongodb.net:27017,ac-hfsjren-shard-00-01.d8m7g8f.mongodb.net:27017,ac-hfsjren-shard-00-02.d8m7g8f.mongodb.net:27017/?ssl=true&replicaSet=atlas-z7p8m3-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.test

database = client['AttributeDress']
collection = database['Attribute']
f = open('D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\AttributeDataSet.json', 'r')
read_file = f.read()
with open('D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\AttributeDataSet.json') as file:
    file_data = json.load(file)
collection.insert_one(file_data)

collection = database['Sales']
f = open('D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\DressSalesDataSet.json', 'r')
read_file = f.read()
with open('D:\\FSDS-iNeuron\\3.Resource\\DataFSDS\\DressSalesDataSet.json') as file:
    file_data = json.load(file)
collection.insert_one(file_data)

# %%
#In sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID

connection = conn.connect(host = "localhost" , user ="root" , passwd = "Sai@9556332113" )
cursor = connection.cursor()

cursor.execute('use sqldb;')

query = 'select * from attributeTable left  join salesTable on attributeTable.Dress_ID = salesTable.Dress_Id;'

cursor.execute(query)

#for i in cursor.fetchall():
#    print(i)

# %%
#Write a sql query to find out how many unique dress that we have based on dress id

connection = conn.connect(host = "localhost" , user ="root" , passwd = "Sai@9556332113" )
cursor = connection.cursor()
cursor.execute('use sqldb;')

query = 'select count(distinct(dress_id)) from attributeTable;'

cursor.execute(query)
print(cursor.fetchall()[0][0])
# Out:
# 475

# %%
#Try to find out how many dress is having recommendation 0

connection = conn.connect(host = "localhost" , user ="root" , passwd = "Sai@9556332113" )
cursor = connection.cursor()
cursor.execute('use sqldb;')

query = 'select recommendation, count(recommendation) from attributeTable group by recommendation;'
cursor.execute(query)
print(cursor.fetchall()[1][1])
# Out:
# 580

# %%
#Try to find out total dress sell for individual dress id

connection = conn.connect(host = "localhost" , user ="root" , passwd = "Sai@9556332113" )
cursor = connection.cursor()
cursor.execute('use sqldb;')

query = 'select Dress_ID, sum(`29/8/2013` +`31/8/2013` +`2013-02-09` +`2013-04-09` +`2013-06-09` +`2013-08-09` +`2013-10-09` +`2013-12-09` +`14/9/2013` +`16/9/2013` +`18/9/2013` +`20/9/2013` +`22/9/2013` +`24/9/2013` +`26/9/2013` +`28/9/2013` +`30/9/2013` +`2013-02-10` +`2013-04-10` +`2013-06-10` +`2010-08-10` +`2013-10-10` +`2013-12-10`) as Total from salesTable group by Dress_ID'
cursor.execute(query)

print('Dress_Id',',','Total')
cursor.fetchall()
# Out:
# Dress_Id , Total
# [('1006032852', 151958.0),
#  ('1212192089', 104512.0),
#  ('1190380701', 446.0),
#  ('966005983', 79382.0),
#  ('876339541', 88154.0),
#  ('1068332458', 914.0),
#  ('1220707172', 14656.0),
#  ('1219677488', 10368.0),
#  ('1113094204', 988.0),
#  ('985292672', 600.0),
#  ('1117293701', 3822.0),
#  ('898481530', 5684.0),
#  ('957723897', 99966.0),
#  ('749031896', 150692.0),
#  ('1055411544', 2190.0),
#  ('1162628131', 4638.0),
#  ('624314841', 95996.0),
#  ('830467746', 802.0),
#  ('840857118', 598.0),
#  ('1113221101', 19996.0),
#  ('861754372', 12350.0),
#  ('856178100', 62934.0),
#  ('1122989777', 10432.0),
#  ('840516484', 84694.0),
#  ('768517084', 214.0),
#  ('1139843344', 1036.0),
#  ('1004212992', 96880.0),
#  ('1235426503', 9392.0),
#  ('942808364', 23036.0),
#  ('629131530', 311854.0),
#  ('851945460', 52992.0),
#  ('1150275464', 11476.0),
#  ('1026634314', 36368.0),
#  ('978773911', 46400.0),
#  ('827791337', 83750.0),
#  ('640823350', 59056.0),
# ...

# %%
# 10. Try to find out a third highest most selling dress id


connection = conn.connect(host = "localhost" , user ="root" , passwd = "Sai@9556332113" )
cursor = connection.cursor()
cursor.execute('use sqldb;')

query = 'select Dress_ID, sum(29/8/2013 +31/8/2013 +2013-02-09 +2013-04-09 +2013-06-09 +2013-08-09 +2013-10-09 +2013-12-09 +14/9/2013 +16/9/2013 +18/9/2013 +20/9/2013 +22/9/2013 +24/9/2013 +26/9/2013 +28/9/2013 +30/9/2013 +2013-02-10 +2013-04-10 +2013-06-10 +2010-08-10 +2013-10-10 +2013-12-10) as Total from salesTable group by Dress_ID order by Total desc limit 3'
cursor.execute(query)
print(f'Dress ID with third highest sales is : {cursor.fetchall()[2][0]}')
# Out:
# Dress ID with third highest sales is : 1219677488
